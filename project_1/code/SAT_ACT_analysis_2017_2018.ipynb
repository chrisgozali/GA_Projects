# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Executive Summary
#
# The College Entrance Examination Board (or "College Board") was founded in 1899 with the vision of creating standardized college entrance testing. The first SAT was conducted in 1929 and was based on an intelligence test first created for the US army in WWI. This was followed by several years of slow growth and College Board made several adjustments to the tests. During WWII, College Board administered SAT-like tests for vocational testing in the US navy. It was only after WWII that SAT testing had a breakthrough. A law had been passed to grant WWII veterans cash relief for college tuition. This incentivised many veterans to seek college education. With no other standardized testing method during the 1940-1950s the SATs experienced a sharp increase in the number of test takers.
#
# The American College Testing (ACT) program was created in 1959. Its founders saw a need for a more widely used college testing system and one that measures academic preparation. At this point, the use of the SATs was mainly in northeastern US and not widespread enough. The ACTs included testing for English, Math, Natural Sciences as well as Social Studies, allowing for academic placement in addition to admissions.The ACTs eventually became a close competitor to the SATs, with the number of students taking the ACTs exceeding the number of students taking the SATs in 2010. ACT tests administered continued to rise sharply while SAT testing plateaued. This [chart:](https://www.erikthered.com/tutor/historical-sat-act-test-takers-both.pdf) shows the historical trends regarding the number of test takers for both tests.
#
# With these tests being the two largest for standardized testing, most students would opt to pick one over the other. In 2013, the SATs were redesigned to better suit the needs of prospective students and colleges. These changes would hopefully encourage students to pick the SATs as their college entrance test of choice.
#
# [Source: A (Mostly) Brief History Of The SAT And ACT Tests](https://www.erikthered.com/tutor/sat-act-history.html#y2011)
#
#
# ## Problem Statement
#
# ### Audience:
# College Board Executives (non-technical)
#
# ### Objective:
# We are presented with the 2017 and 2018 SAT and ACT data by state. This project aims to identify trends between SAT/ACT participation rates, **determine suitable strategies to best improve SAT participation rates** and **narrow down the list of states College Board to most efficiently channel its resources**.
#
#
# ## Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# ### **Adding appropriate libraries**

# %%
# Import NumPy and Pandas:
import numpy as np
import pandas as pd

# Import matplotlib.pyplot and Seaborn:
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# ### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#read csv files using panda
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# ### 2. Display Data
#
# Print the first 10 rows of each dataframe

# %%
#First 10 rows of SAT 2017 data
sat_2017.head(n=10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#First 10 rows of ACT 2017 data
act_2017.head(n=10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# ### 3. Verbally Describe Data
# #### Performing general checks on dataframe:
# - Dataframe shape
# - Missing values
# - Describe statistics

# %%
#Check no of rows, column in dataframe
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
#checking for missing values
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
#Checking dataframe statistics
sat_2017.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   569.117647  45.666901  482.0
# Math                                 51.0   547.627451  84.909119   52.0
# Total                                51.0  1126.098039  92.494812  950.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   533.5   559.0   613.0   644.0
# Math                                 522.0   548.0   599.0   651.0
# Total                               1055.5  1107.0  1212.0  1295.0

# %%
act_2017.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %% [markdown]
# ### 4a. Does the data look complete?
# ### 4b. Are there any obvious issues with the observations?
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# #### Observations:
# The data contains information about the component and total scores for SAT/ACT in 2017 for each state in the USA. Information about the participation rates by state for the respective tests are also included. There is an additional row in ACT scores describing nationwide results. This is not present in SAT scores. The data looks complete as there are no missing values, and all 50 states are represented. There are however some possible issues with some observations, such as a significantly low minimum math score in the 2017 SATs, and a significantly low minimum science score for 2017 ACTs. This will be further expanded upon below.
# ##### Range of possible scores for the SATs and ACTs:
# For SATs, the scoring system allows values between 200 - 800 for each subject for a total maximum scoring range of 400 - 1600
# For ACTs, the scoring system allows values between 1 - 36 for each test. The composite score is the average of 4 tests rounded to the nearest whole number

# %% [markdown]
# ### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#Checking datatypes
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# **

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# **

# %%
#Checking the different values in Composite column
act_2017['Composite'].value_counts()
# Out:
# 21.4     3
# 19.8     3
# 20.3     3
# 20.4     2
# 24.1     2
# 23.6     2
# 24.2     2
# 19.7     2
# 21.8     2
# 21.9     2
# 19.4     2
# 24.0     1
# 19.1     1
# 19.0     1
# 23.9     1
# 24.3     1
# 25.5     1
# 18.6     1
# 21.7     1
# 20.5     1
# 23.8     1
# 19.5     1
# 20.8     1
# 17.8     1
# 19.2     1
# 20.7     1
# 22.3     1
# 22.8     1
# 25.4     1
# 23.7     1
# 18.7     1
# 21.0     1
# 20.2x    1
# 25.2     1
# 21.5     1
# 22.0     1
# 22.6     1
# 20.0     1
# Name: Composite, dtype: int64

# %% [markdown]
# #### Observations:
# In SAT 2017 dataframe, participation is interpreted as a string. This is due to the % symbol. This can be converted to a float since it is a percentage
#
# In ACT 2017 dataframe,both participation and composite are interpreted as strings
#
# There is an extra x in one entry in ACT 2017 Composite scores, possibly a typo error. This will have to be removed later on

# %% [markdown]
# ### Cleaning the data

# %%
#create new dataframe to make changes and set state name as index
sat_2017_i = sat_2017
sat_2017_i = sat_2017.set_index('State')

act_2017_i = act_2017
act_2017_i = act_2017.set_index('State')

# %%
#removing the % symbol in SAT participation and converting the number to a float where 1  = 100%
sat_2017_i['Participation'] = sat_2017_i['Participation'].map(lambda x: (float(x.replace('%','')) * 0.01))

# %%
#checking that the participation values have changed
sat_2017_i['Participation'].sort_values().head(10)
# Out:
# State
# North Dakota    0.02
# Mississippi     0.02
# Iowa            0.02
# Missouri        0.03
# Utah            0.03
# South Dakota    0.03
# Nebraska        0.03
# Wisconsin       0.03
# Minnesota       0.03
# Wyoming         0.03
# Name: Participation, dtype: float64

# %%
#removing the % symbol in ACT participation and converting the number to a float where 1  = 100%
act_2017_i['Participation'] = act_2017_i['Participation'].map(lambda x: (float(x.replace('%','')) * 0.01))

# %%
#checking that the participation values have changed
act_2017_i['Participation'].sort_values().head(10)
# Out:
# State
# Maine            0.08
# New Hampshire    0.18
# Delaware         0.18
# Rhode Island     0.21
# Pennsylvania     0.23
# Maryland         0.28
# Washington       0.29
# Virginia         0.29
# Michigan         0.29
# Massachusetts    0.29
# Name: Participation, dtype: float64

# %%
#removing the extra x character in ACT composite score
act_2017_i['Composite'] = act_2017_i['Composite'].map(lambda x: (float(x.replace('x',''))))

# %%
#checking that the participation values have changed
act_2017_i['Composite'].sort_values()
# Out:
# State
# Nevada                  17.8
# Mississippi             18.6
# South Carolina          18.7
# Hawaii                  19.0
# North Carolina          19.1
# Alabama                 19.2
# Arkansas                19.4
# Oklahoma                19.4
# Louisiana               19.5
# Arizona                 19.7
# New Mexico              19.7
# Alaska                  19.8
# Tennessee               19.8
# Florida                 19.8
# Kentucky                20.0
# Wyoming                 20.2
# North Dakota            20.3
# Montana                 20.3
# Utah                    20.3
# West Virginia           20.4
# Missouri                20.4
# Wisconsin               20.5
# Texas                   20.7
# Colorado                20.8
# National                21.0
# Illinois                21.4
# Nebraska                21.4
# Georgia                 21.4
# Minnesota               21.5
# Kansas                  21.7
# South Dakota            21.8
# Oregon                  21.8
# ...

# %% [markdown]
# #### Changing incorrect data:
# The **2017 SAT Math score in Maryland** looks like an outlier. It is off from other scores by a magnitude of 10
# The data was probably entered incorrectly
#
# We can cross refernce the data with another data [Source: 2017 Maryland SAT Suite of Assessments Annual Report](https://reports.collegeboard.org/pdf/2017-maryland-sat-suite-assessments-annual-report.pdf-0)
# in the collegeboard report, the average math score for Maryland in 2017 was **524**
#
# Similarly, the **2017 ACT science score in Maryland** looks like an outlier. It is off from other scores by a magnitude of 10
# The data was also probably entered incorrectly
#
# Upon further research, the correct science score for Maryland can be found in online publications
# [Source: ACT 2017 Average Scores by State](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf)
# The correct science score for maryland should be **23.2**

# %%
#checking for any scores that exceed the allowable range
# 200 - 800 for individual SAT scores
# 400 - 1600 for total SAT score
#1 - 36 for all ACT scores
sat_2017_i['Math'].sort_values().head()
# Out:
# State
# Maryland                 52
# District of Columbia    468
# Delaware                492
# Idaho                   493
# Michigan                495
# Name: Math, dtype: int64

# %%
#replacing the math score for maryland with the corrected score
sat_2017_i.at['Maryland','Math'] = 524

# %%
#check the updated score
sat_2017_i['Math']['Maryland']
# Out:
# 524

# %%
#check values for ACT scores
act_2017_i['Science'].sort_values().head()
# Out:
# State
# Maryland           2.3
# Nevada            18.2
# Mississippi       18.8
# South Carolina    18.9
# North Carolina    19.3
# Name: Science, dtype: float64

# %%
#replacing the math score for maryland with the corrected score
act_2017_i.at['Maryland','Science'] = 23.2

# %%
#check the updated score
act_2017_i['Science']['Maryland']
# Out:
# 23.2

# %% [markdown]
# ### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017_i.dtypes
# Out:
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2017_i.dtypes
# Out:
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# ### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %% [markdown]
# ### NOTE:
# **The required fixes were done in a previous step.**
#
# To summarize the adjustments made:
#
# - Both SAT and ACT participation rates were being recognised as object (string) types as they included the '%' symbol denoting a percentage. They were converted to floats where 1.0 represents 100%
#
# - ACT composite scores were recognised as object(string) type as there was an extra 'x' character in one of the entries. After removing the 'x', the values were converted to float type
#
# - The SAT math and ACT science scores for the state of Maryland were found to be incorrect after cross referencing with additional data and the scores were changed appropriately

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#check current column names for sat
sat_2017_i.columns
# Out:
# Index(['Participation', 'Evidence-Based Reading and Writing', 'Math', 'Total'], dtype='object')

# %%
#check current column names for act
act_2017_i.columns
# Out:
# Index(['Participation', 'English', 'Math', 'Reading', 'Science', 'Composite'], dtype='object')

# %%
#initialize dictionary of new column names for sat and act
new_columns_sat = {'Participation' : 'sat_participation',
                   'Evidence-Based Reading and Writing' : 'sat_read_write',
                   'Math' : 'sat_math',
                   'Total' : 'sat_total'    
}

new_columns_act = {'Participation' : 'act_participation',
                   'English' : 'act_english',
                   'Math' : 'act_math',
                   'Reading' : 'act_reading',
                   'Science' : 'act_science',
                   'Composite' : 'act_composite',
                   'Percentage of Students Tested' : 'act_participation',
                   'Average English Score' : 'act_english',
                   'Average Math Score' : 'act_math',
                   'Average Reading Score' : 'act_reading',
                   'Average Science Score' : 'act_science',
                   'Average Composite Score' : 'act_composite'}

# %%
#code
#renaming the columns with the new names stated above
sat_2017_i.rename(columns = new_columns_sat, inplace = True)
act_2017_i.rename(columns = new_columns_act, inplace = True)

# %%
#check new column names
sat_2017_i.columns
# Out:
# Index(['sat_participation', 'sat_read_write', 'sat_math', 'sat_total'], dtype='object')

# %%
#check new column names
act_2017_i.columns
# Out:
# Index(['act_participation', 'act_english', 'act_math', 'act_reading',
#        'act_science', 'act_composite'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |sat_participation|float|sat_2017_i, sat_2018_i|SAT participation rate for a particular state (1.0 means 100% of students in specified state participated in SAT|
# |sat_read_write|int|sat_2017_i, sat_2018_i|Average SAT Evidence-Based Reading and Writing test score for a particular state (possible range from 200-800)|
# |sat_math|int|sat_2017_i, sat_2018_i|Average SAT Math test score for a particular state (possible range from 200-800)|
# |sat_total|int|sat_2017_i, sat_2018_i|Average SAT Total score for a particular state. The total score is the sum of the two individual tests ( Evidence-Based Reading and Writing, Math) (possible range from 400-1600)|
# |act_participation|float|act_2017_i, act_2018_i|ACT participation rate for a particular state (1.0 means 100% of students in specified state participated in ACT|
# |act_english|float|act_2017_i, act_2018_i|Average ACT English test score for a particular state (possible range from 1-24)|
# |act_math|float|act_2017_i, act_2018_i|Average ACT Math test score for a particular state (possible range from 1-24)|
# |act_reading|float|act_2017_i, act_2018_i|Average ACT Reading test score for a particular state (possible range from 1-24)|
# |act_science|float|act_2017_i, act_2018_i|Average ACT Science test score for a particular state (possible range from 1-24)|
# |act_composite|float|act_2017_i, act_2018_i|Average ACT composite for a particular state. ACT composite scores are calculated as the average of the 4 individual tests (English, Math, Reading, Science) (possible range from 1-24)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %% [markdown]
# #### Answer:
# ACT dataframe contains the row called **'National'** summarizing the national average. This row is redundant as the national averages can be calculated using the other data.

# %%
act_2017_i.head()
# Out:
#           act_participation  act_english  act_math  act_reading  act_science  \
# State
# National               0.60         20.3      20.7         21.4         21.0
# Alabama                1.00         18.9      18.4         19.7         19.4
# Alaska                 0.65         18.7      19.8         20.4         19.9
# Arizona                0.62         18.6      19.8         20.1         19.8
# Arkansas               1.00         18.9      19.0         19.7         19.5
#
#           act_composite
# State
# National           21.0
# Alabama            19.2
# Alaska             19.8
# Arizona            19.7
# Arkansas           19.4

# %%
#code
act_2017_i.drop('National', axis = 0, inplace = True)

# %%
#Check that the row is now gone
act_2017_i.head()
# Out:
#             act_participation  act_english  act_math  act_reading  \
# State
# Alabama                  1.00         18.9      18.4         19.7
# Alaska                   0.65         18.7      19.8         20.4
# Arizona                  0.62         18.6      19.8         20.1
# Arkansas                 1.00         18.9      19.0         19.7
# California               0.31         22.5      22.7         23.1
#
#             act_science  act_composite
# State
# Alabama            19.4           19.2
# Alaska             19.9           19.8
# Arizona            19.8           19.7
# Arkansas           19.5           19.4
# California         22.2           22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
combined_2017 = pd.merge(sat_2017_i, act_2017_i, on = 'State', how = 'inner')

# %%
combined_2017.head()
# Out:
#             sat_participation  sat_read_write  sat_math  sat_total  \
# State
# Alabama                  0.05             593       572       1165
# Alaska                   0.38             547       533       1080
# Arizona                  0.30             563       553       1116
# Arkansas                 0.03             614       594       1208
# California               0.53             531       524       1055
#
#             act_participation  act_english  act_math  act_reading  \
# State
# Alabama                  1.00         18.9      18.4         19.7
# Alaska                   0.65         18.7      19.8         20.4
# Arizona                  0.62         18.6      19.8         20.1
# Arkansas                 1.00         18.9      19.0         19.7
# California               0.31         22.5      22.7         23.1
#
#             act_science  act_composite
# State
# Alabama            19.4           19.2
# Alaska             19.9           19.8
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# #### Data Import and checking

# %%
#importing csv files
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
#previewing the SAT 2018 data
sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
#previewing the ACT 2018 data
act_2018.head(10)
# Out:
#                   State  Percentage of Students Tested  \
# 0               Alabama                            100
# 1                Alaska                             33
# 2               Arizona                             66
# 3              Arkansas                            100
# 4            California                             27
# 5              Colorado                             30
# 6           Connecticut                             26
# 7              Delaware                             17
# 8  District of Columbia                             32
# 9               Florida                             66
#
#    Average Composite Score  Average English Score  Average Math Score  \
# 0                     19.1                   18.9                18.3
# 1                     20.8                   19.8                20.6
# 2                     19.2                   18.2                19.4
# 3                     19.4                   19.1                18.9
# ...

# %%
#checking data types for each column
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# Participation is recognised as an object (string). It needs to be changed to a float type to match the 2017 combined data

# %%
act_2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %% [markdown]
# In ACT 2018, the percentage of students tested is recognised as an integer. 100% is represented by 100.
# It needs to be changed to a float type to match the 2017 combined data.

# %%
#checking for missing values
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2018.isnull().sum()
# Out:
# State                            0
# Percentage of Students Tested    0
# Average Composite Score          0
# Average English Score            0
# Average Math Score               0
# Average Reading Score            0
# Average Science Score            0
# dtype: int64

# %% [markdown]
# There are no missing values in both the dataframes

# %% [markdown]
# #### Data Cleaning

# %%
#create new dataframes to make the required changes on
sat_2018_i = sat_2018
sat_2018_i = sat_2018.set_index('State')

act_2018_i = act_2018
act_2018_i = act_2018.set_index('State')

# %%
sat_2018_i.head()
# Out:
#            Participation  Evidence-Based Reading and Writing  Math  Total
# State
# Alabama               6%                                 595   571   1166
# Alaska               43%                                 562   544   1106
# Arizona              29%                                 577   572   1149
# Arkansas              5%                                 592   576   1169
# California           60%                                 540   536   1076

# %%
act_2018_i.head()
# Out:
#             Percentage of Students Tested  Average Composite Score  \
# State
# Alabama                               100                     19.1
# Alaska                                 33                     20.8
# Arizona                                66                     19.2
# Arkansas                              100                     19.4
# California                             27                     22.7
#
#             Average English Score  Average Math Score  Average Reading Score  \
# State
# Alabama                      18.9                18.3                   19.6
# Alaska                       19.8                20.6                   21.6
# Arizona                      18.2                19.4                   19.5
# Arkansas                     19.1                18.9                   19.7
# California                   22.5                22.5                   23.0
#
#             Average Science Score
# State
# Alabama                      19.0
# ...

# %%
#rename columns to match column names from 2017
sat_2018_i.rename(columns = new_columns_sat, inplace = True)
act_2018_i.rename(columns = new_columns_act, inplace = True)

# %%
#check column names
sat_2018_i.columns
# Out:
# Index(['sat_participation', 'sat_read_write', 'sat_math', 'sat_total'], dtype='object')

# %%
act_2018_i.columns
# Out:
# Index(['act_participation', 'act_composite', 'act_english', 'act_math',
#        'act_reading', 'act_science'],
#       dtype='object')

# %%
#modifying the data types
sat_2018_i['sat_participation'] = sat_2018_i['sat_participation'].map(lambda x: (float(x.replace('%','')) * 0.01))
sat_2018_i.head()
# Out:
#             sat_participation  sat_read_write  sat_math  sat_total
# State
# Alabama                  0.06             595       571       1166
# Alaska                   0.43             562       544       1106
# Arizona                  0.29             577       572       1149
# Arkansas                 0.05             592       576       1169
# California               0.60             540       536       1076

# %%
act_2018_i['act_participation'] = act_2018_i['act_participation'].map(lambda x: (float(x) * 0.01))
act_2018_i.head()
# Out:
#             act_participation  act_composite  act_english  act_math  \
# State
# Alabama                  1.00           19.1         18.9      18.3
# Alaska                   0.33           20.8         19.8      20.6
# Arizona                  0.66           19.2         18.2      19.4
# Arkansas                 1.00           19.4         19.1      18.9
# California               0.27           22.7         22.5      22.5
#
#             act_reading  act_science
# State
# Alabama            19.6         19.0
# Alaska             21.6         20.7
# Arizona            19.5         19.2
# Arkansas           19.7         19.4
# California         23.0         22.1

# %% [markdown]
# #### Merging the 2018 test scores

# %%
combined_2018 = pd.merge(sat_2018_i, act_2018_i, on = 'State', how = 'inner')

# %%
combined_2018.head()
# Out:
#             sat_participation  sat_read_write  sat_math  sat_total  \
# State
# Alabama                  0.06             595       571       1166
# Alaska                   0.43             562       544       1106
# Arizona                  0.29             577       572       1149
# Arkansas                 0.05             592       576       1169
# California               0.60             540       536       1076
#
#             act_participation  act_composite  act_english  act_math  \
# State
# Alabama                  1.00           19.1         18.9      18.3
# Alaska                   0.33           20.8         19.8      20.6
# Arizona                  0.66           19.2         18.2      19.4
# Arkansas                 1.00           19.4         19.1      18.9
# California               0.27           22.7         22.5      22.5
#
#             act_reading  act_science
# State
# Alabama            19.6         19.0
# Alaska             21.6         20.7
# ...

# %%
combined_2018.to_csv('../data/combined_2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.concat([combined_2017,combined_2018],keys = ['2017','2018'])

# %%
final
# Out:
#                     sat_participation  sat_read_write  sat_math  sat_total  \
#      State
# 2017 Alabama                     0.05             593       572       1165
#      Alaska                      0.38             547       533       1080
#      Arizona                     0.30             563       553       1116
#      Arkansas                    0.03             614       594       1208
#      California                  0.53             531       524       1055
# ...                               ...             ...       ...        ...
# 2018 Virginia                    0.68             567       550       1117
#      Washington                  0.69             543       538       1081
#      West Virginia               0.28             513       486        999
#      Wisconsin                   0.03             641       653       1294
#      Wyoming                     0.03             633       625       1257
#
# ...

# %%
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe()
# Out:
#        sat_participation  sat_read_write    sat_math    sat_total  \
# count         102.000000      102.000000  102.000000   102.000000
# mean            0.427745      566.401961  556.558824  1123.058824
# std             0.362527       46.442823   47.213770    92.915678
# min             0.020000      480.000000  468.000000   950.000000
# 25%             0.040000      534.250000  523.000000  1055.250000
# 50%             0.455000      554.500000  545.500000  1099.000000
# 75%             0.700000      613.500000  595.000000  1209.500000
# max             1.000000      644.000000  655.000000  1298.000000
#
#        act_participation  act_english    act_math  act_reading  act_science  \
# count         102.000000   102.000000  102.000000   102.000000   102.000000
# mean            0.634510    20.959804   21.153922    22.014706    21.398039
# std             0.330105     2.388722    1.999291     2.107337     1.797742
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
# inputs: n, x, mean

def get_std(data):
    n = len(data)
    miu = data.mean()
    var = 0
    for index, x in enumerate(data):
        if x != None:
            var += ((x - miu) ** 2)/n
        else:
            continue
    std = round((var)**0.5,4)
    return std

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.columns[0]
# Out:
# 'sat_participation'

# %%
#Code:

sd = final.apply(get_std).to_dict()
sd
# Out:
# {'sat_participation': 0.3607,
#  'sat_read_write': 46.2146,
#  'sat_math': 46.9818,
#  'sat_total': 92.4591,
#  'act_participation': 0.3285,
#  'act_english': 2.377,
#  'act_math': 1.9895,
#  'act_reading': 2.097,
#  'act_science': 1.7889,
#  'act_composite': 2.0437}

# %%
np.std(final)
# Out:
# sat_participation     0.360745
# sat_read_write       46.214602
# sat_math             46.981760
# sat_total            92.459087
# act_participation     0.328483
# act_english           2.376984
# act_math              1.989466
# act_reading           2.096982
# act_science           1.788908
# act_composite         2.043663
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# #### Observations:
#
# The manually calculated standard deviations are **close to, but not exactly the same** as the output from pandas describe.
#
# The manual calculations, however, **match the output from numpy's std method.**
#
# The reason for this difference is that the pandas describe method calculates a **normalized standard deviation**. In the formula, the result of the summation is **divided by (n-1) instead of n.**

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#previewing data
final.head()
# Out:
#                  sat_participation  sat_read_write  sat_math  sat_total  \
#      State
# 2017 Alabama                  0.05             593       572       1165
#      Alaska                   0.38             547       533       1080
#      Arizona                  0.30             563       553       1116
#      Arkansas                 0.03             614       594       1208
#      California               0.53             531       524       1055
#
#                  act_participation  act_english  act_math  act_reading  \
#      State
# 2017 Alabama                  1.00         18.9      18.4         19.7
#      Alaska                   0.65         18.7      19.8         20.4
#      Arizona                  0.62         18.6      19.8         20.1
#      Arkansas                 1.00         18.9      19.0         19.7
#      California               0.31         22.5      22.7         23.1
#
#                  act_science  act_composite
#      State
# ...

# %%
print(f'Lowest participation rates by state for 2017 SATs')
final.loc['2017'].sort_values('sat_participation')[['sat_participation']].head(10)
# Out:
# Lowest participation rates by state for 2017 SATs
#               sat_participation
# State
# North Dakota               0.02
# Mississippi                0.02
# Iowa                       0.02
# Missouri                   0.03
# Utah                       0.03
# South Dakota               0.03
# Nebraska                   0.03
# Wisconsin                  0.03
# Minnesota                  0.03
# Wyoming                    0.03

# %%
print(f'Lowest participation rates by state for 2018 SATs')
final.loc['2018'].sort_values('sat_participation')[['sat_participation']].head(10)
# Out:
# Lowest participation rates by state for 2018 SATs
#               sat_participation
# State
# North Dakota               0.02
# Wyoming                    0.03
# South Dakota               0.03
# Nebraska                   0.03
# Wisconsin                  0.03
# Mississippi                0.03
# Iowa                       0.03
# Utah                       0.04
# Minnesota                  0.04
# Louisiana                  0.04

# %%
print(f'Highest participation rates by state for 2017 SATs')
final.loc['2017'].sort_values('sat_participation', ascending = False)[['sat_participation']].head(10)
# Out:
# Highest participation rates by state for 2017 SATs
#                       sat_participation
# State
# District of Columbia               1.00
# Michigan                           1.00
# Connecticut                        1.00
# Delaware                           1.00
# New Hampshire                      0.96
# Maine                              0.95
# Idaho                              0.93
# Florida                            0.83
# Massachusetts                      0.76
# Rhode Island                       0.71

# %%
print(f'Highest participation rates by state for 2018 SATs')
final.loc['2018'].sort_values('sat_participation', ascending = False)[['sat_participation']].head(10)
# Out:
# Highest participation rates by state for 2018 SATs
#                       sat_participation
# State
# Colorado                           1.00
# Connecticut                        1.00
# Delaware                           1.00
# Michigan                           1.00
# Idaho                              1.00
# Maine                              0.99
# Illinois                           0.99
# Rhode Island                       0.97
# New Hampshire                      0.96
# District of Columbia               0.92

# %% [markdown]
# **States with lowest SAT participation rates (2%)**
#
# |Year|2017|2018|
# |---|---|---|
# |---|North Dakota|North Dakota|
# |---|Mississippi|---|
# |---|Iowa|---|

# %% [markdown]
# **States with highest SAT participation rates (100%)**
#
# |Year|2017|2018|
# |---|---|---|
# |---|District of Columbia|---|
# |---|Michigan|Michigan|
# |---|Connecticut|Connecticut|
# |---|Delaware|Delaware|
# |---|---|Colorado|
# |---|---|Idaho|

# %% [markdown]
# #### Observations:
# - The gap between the lowest participation rate and highest participation rate is enormous.
# - North Dakota is at the bottom of the list for participation for both years.
# - Michigan, Connecticut and Delaware had a 100% participation rate for both years.

# %%
print(f'Lowest participation rates by state for 2017 ACTs')
final.loc['2017'].sort_values('act_participation')[['act_participation']].head(10)
# Out:
# Lowest participation rates by state for 2017 ACTs
#                act_participation
# State
# Maine                       0.08
# New Hampshire               0.18
# Delaware                    0.18
# Rhode Island                0.21
# Pennsylvania                0.23
# Maryland                    0.28
# Vermont                     0.29
# Massachusetts               0.29
# Michigan                    0.29
# Virginia                    0.29

# %%
print(f'Lowest participation rates by state for 2018 ACTs')
final.loc['2018'].sort_values('act_participation')[['act_participation']].head(10)
# Out:
# Lowest participation rates by state for 2018 ACTs
#                act_participation
# State
# Maine                       0.07
# Rhode Island                0.15
# New Hampshire               0.16
# Delaware                    0.17
# Pennsylvania                0.20
# Michigan                    0.22
# Washington                  0.24
# Vermont                     0.24
# Virginia                    0.24
# Massachusetts               0.25

# %%
print(f'Highest participation rates by state for 2017 ACTs')
final.loc['2017'].sort_values('act_participation', ascending = False)[['act_participation']].head(20)
# Out:
# Highest participation rates by state for 2017 ACTs
#                 act_participation
# State
# Alabama                      1.00
# Kentucky                     1.00
# Wisconsin                    1.00
# Utah                         1.00
# Tennessee                    1.00
# South Carolina               1.00
# Oklahoma                     1.00
# North Carolina               1.00
# Nevada                       1.00
# Montana                      1.00
# Mississippi                  1.00
# Minnesota                    1.00
# Louisiana                    1.00
# Missouri                     1.00
# Wyoming                      1.00
# Colorado                     1.00
# Arkansas                     1.00
# North Dakota                 0.98
# Illinois                     0.93
# Hawaii                       0.90

# %%
print(f'Highest participation rates by state for 2018 ACTs')
final.loc['2018'].sort_values('act_participation', ascending = False)[['act_participation']].head(20)
# Out:
# Highest participation rates by state for 2018 ACTs
#                 act_participation
# State
# Alabama                      1.00
# Kentucky                     1.00
# Wisconsin                    1.00
# Utah                         1.00
# Tennessee                    1.00
# South Carolina               1.00
# Ohio                         1.00
# Oklahoma                     1.00
# North Carolina               1.00
# Nevada                       1.00
# Nebraska                     1.00
# Montana                      1.00
# Mississippi                  1.00
# Louisiana                    1.00
# Missouri                     1.00
# Wyoming                      1.00
# Arkansas                     1.00
# Minnesota                    0.99
# North Dakota                 0.98
# Hawaii                       0.89

# %% [markdown]
# **States with lowest ACT participation rates**
#
# |Year|2017|2018|
# |---|---|---|
# |---|Maine (8%)|Maine (7%)|

# %% [markdown]
# **States with highest ACT participation rates (100%)**
#
# |Year|2017|2018|
# |---|---|---|
# |---|Alabama|Alabama|
# |---|Kentucky|Kentucky|
# |---|Wisconsin|Wisconsin|
# |---|Utah|Utah|
# |---|Tennessee|Tennessee|
# |---|South Carolina|South Carolina|
# |---|---|Ohio|
# |---|Olkahoma|Olkahoma|
# |---|North Carolina|North Carolina|
# |---|Nevada|Nevada|
# |---|---|Nebraska|
# |---|Montana|Montana|
# |---|Mississipi|Mississipi|
# |---|Minnesota|Minnesota|
# |---|Louisiana|Louisiana|
# |---|Missouri|Missouri|
# |---|Wyoming|Wyoming|
# |---|Colorado|---|
# |---|Arkansas|Arkansas|

# %% [markdown]
# #### Observations:
# - Like the SATs, the gap between the lowest participation rate and highest participation rate is also enormous.
# - However unlike the SATs, there are a lot of states that have 100% participation rate for both years.
# - Maine is at the bottom of the list for participation for both years.
# - Most states which achieved 100% participation in 2017 also did so in 2018. Exceptions to this include: Ohio, Nebraska, Minnesota and Colorado which achieved 100% participation in one of the two years.

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %%
print(f'Lowest mean total score by state for 2017 SATs and the corresponding participation rate')
final.loc['2017'].sort_values('sat_total')[['sat_total','sat_participation']].head()
# Out:
# Lowest mean total score by state for 2017 SATs and the corresponding participation rate
#                       sat_total  sat_participation
# State
# District of Columbia        950               1.00
# Delaware                    996               1.00
# Idaho                      1005               0.93
# Michigan                   1005               1.00
# Maine                      1012               0.95

# %%
print(f'Lowest mean total score by state for 2018 SATs and the corresponding participation rate')
final.loc['2018'].sort_values('sat_total')[['sat_total','sat_participation']].head()
# Out:
# Lowest mean total score by state for 2018 SATs and the corresponding participation rate
#                       sat_total  sat_participation
# State
# District of Columbia        977               0.92
# Delaware                    998               1.00
# West Virginia               999               0.28
# Idaho                      1001               1.00
# Utah                       1010               0.04

# %% [markdown]
# #### Lowest SAT scores by state in 2017 and 2018:
# **District of Columbia** had the lowest average SAT total score for both years, at 950 and 977 respectively. It also has a high participation rate of 100% and 92% respectively.

# %%
print(f'Highest mean total score by state for 2017 SATs and the corresponding participation rate')
final.loc['2017'].sort_values('sat_total', ascending = False)[['sat_total','sat_participation']].head()
# Out:
# Highest mean total score by state for 2017 SATs and the corresponding participation rate
#            sat_total  sat_participation
# State
# Minnesota       1295               0.03
# Wisconsin       1291               0.03
# Iowa            1275               0.02
# Missouri        1271               0.03
# Kansas          1260               0.04

# %%
print(f'Highest mean total score by state for 2018 SATs and the corresponding participation rate')
final.loc['2018'].sort_values('sat_total', ascending = False)[['sat_total','sat_participation']].head()
# Out:
# Highest mean total score by state for 2018 SATs and the corresponding participation rate
#               sat_total  sat_participation
# State
# Minnesota          1298               0.04
# Wisconsin          1294               0.03
# North Dakota       1283               0.02
# Iowa               1265               0.03
# Kansas             1265               0.04

# %% [markdown]
# #### Highest SAT scores by state:
# **Minnesota** had the highest average SAT total score for both years, at 1295 and 1298 respectively. The states which tend to score higher also tend to have low participation rates between 2% to 4%.

# %%
print(f'Lowest mean composite score by state for 2017 ACTs and the corresponding participation rate')
final.loc['2017'].sort_values('act_composite')[['act_composite','act_participation']].head()
# Out:
# Lowest mean composite score by state for 2017 ACTs and the corresponding participation rate
#                 act_composite  act_participation
# State
# Nevada                   17.8                1.0
# Mississippi              18.6                1.0
# South Carolina           18.7                1.0
# Hawaii                   19.0                0.9
# North Carolina           19.1                1.0

# %%
print(f'Lowest mean composite score by state for 2018 ACTs and the corresponding participation rate')
final.loc['2018'].sort_values('act_composite')[['act_composite','act_participation']].head()
# Out:
# Lowest mean composite score by state for 2018 ACTs and the corresponding participation rate
#                 act_composite  act_participation
# State
# Nevada                   17.7               1.00
# South Carolina           18.3               1.00
# Mississippi              18.6               1.00
# Hawaii                   18.9               0.89
# Alabama                  19.1               1.00

# %% [markdown]
# #### Lowest ACT scores by state:
# **Nevada** had the lowest average ACT composite score for both years, at 17.8 and 17.7 respectively. The states with the lowest mean ACT scores also tend to have higher participation rates.

# %%
print(f'Highest mean composite score by state for 2017 ACTs and the corresponding participation rate')
final.loc['2017'].sort_values('act_composite', ascending = False)[['act_composite','act_participation']].head()
# Out:
# Highest mean composite score by state for 2017 ACTs and the corresponding participation rate
#                       act_composite  act_participation
# State
# New Hampshire                  25.5               0.18
# Massachusetts                  25.4               0.29
# Connecticut                    25.2               0.31
# Maine                          24.3               0.08
# District of Columbia           24.2               0.32

# %%
print(f'Highest mean composite score by state for 2018 ACTs and the corresponding participation rate')
final.loc['2018'].sort_values('act_composite', ascending = False)[['act_composite','act_participation']].head()
# Out:
# Highest mean composite score by state for 2018 ACTs and the corresponding participation rate
#                act_composite  act_participation
# State
# Connecticut             25.6               0.26
# Massachusetts           25.5               0.25
# New Hampshire           25.1               0.16
# New York                24.5               0.27
# Michigan                24.4               0.22

# %% [markdown]
# #### Highest ACT scores by state:
# **New Hampshire** had the highest average ACT composite score for 2017 at 25.5
#
# **Connecticut** had the highest average ACT composite score for 2018 at 25.6
#
# The states with high mean composite scores for ACTs also tend to have low participation rates.

# %% [markdown]
# #### Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
#Checking the states which meet the condition of 100% participation in 2017
full_participation_2017 = final.loc['2017'][['sat_participation']][final.loc['2017']['sat_participation'] == 1]
full_participation_2017
# Out:
#                       sat_participation
# State
# Connecticut                         1.0
# Delaware                            1.0
# District of Columbia                1.0
# Michigan                            1.0

# %%
full_participation_2018 = final.loc['2018'][['sat_participation']][final.loc['2018']['sat_participation'] == 1]
full_participation_2018
# Out:
#              sat_participation
# State
# Colorado                   1.0
# Connecticut                1.0
# Delaware                   1.0
# Idaho                      1.0
# Michigan                   1.0

# %%
pd.merge(full_participation_2017, full_participation_2018, on = 'State', how = 'outer')
# Out:
#                       sat_participation_x  sat_participation_y
# State
# Connecticut                           1.0                  1.0
# Delaware                              1.0                  1.0
# District of Columbia                  1.0                  NaN
# Michigan                              1.0                  1.0
# Colorado                              NaN                  1.0
# Idaho                                 NaN                  1.0

# %% [markdown]
# We need to fill in the missing values for participation in 2017, 2018.
#
# That is Colorado and Idaho for 2017, District of Columbia for 2018

# %%
#inserting new rows to include the missing data for comparison between years
full_participation_2017.loc['Colorado'] = final.loc['2017']['sat_participation']['Colorado']
full_participation_2017.loc['Idaho'] = final.loc['2017']['sat_participation']['Idaho']
full_participation_2018.loc['District of Columbia'] = final.loc['2018']['sat_participation']['District of Columbia']

# %%
full_participation = pd.merge(full_participation_2017, full_participation_2018, on = 'State', how = 'outer', suffixes = ('_2017','_2018'))
full_participation
# Out:
#                       sat_participation_2017  sat_participation_2018
# State
# Connecticut                             1.00                    1.00
# Delaware                                1.00                    1.00
# District of Columbia                    1.00                    0.92
# Michigan                                1.00                    1.00
# Colorado                                0.11                    1.00
# Idaho                                   0.93                    1.00

# %% [markdown]
# **District of Columbia** had a 100% participation rate in 2017. This dropped to 92% the following year.
#
# **Idaho** had a 93% participation rate in 2017, then reached 100% in 2018.
#
# **Colorado** is an interesting case which had 11% participation in 2017, then 100% in 2018. *This suggests the implementation of mandatory testing in that state.* Further [research:](https://www.testive.com/colorado-sat-change-2017/) validates this observation.

# %% [markdown]
# #### Do any states show  >50% participation on *both* tests either year?

# %%
sat_majority_2017 = final.loc['2017'][['sat_participation']][final.loc['2017']['sat_participation'] >0.5]

# %%
act_majority_2017 = final.loc['2017'][['act_participation']][final.loc['2017']['act_participation'] >0.5]

# %%
print(f'States with > 50% participation on both tests in 2017')
majority_2017 = pd.merge(sat_majority_2017, act_majority_2017, on = 'State', how = 'outer')
majority_2017.dropna()
# Out:
# States with > 50% participation on both tests in 2017
#          sat_participation  act_participation
# State
# Florida               0.83               0.73
# Georgia               0.61               0.55
# Hawaii                0.55               0.90

# %%
sat_majority_2018 = final.loc['2018'][['sat_participation']][final.loc['2018']['sat_participation'] >0.5]

# %%
act_majority_2018 = final.loc['2018'][['act_participation']][final.loc['2018']['act_participation'] >0.5]

# %%
print(f'States with > 50% participation on both tests in 2018')
majority_2018 = pd.merge(sat_majority_2018, act_majority_2018, on = 'State', how = 'outer')
majority_2018.dropna()
# Out:
# States with > 50% participation on both tests in 2018
#                 sat_participation  act_participation
# State
# Florida                      0.56               0.66
# Georgia                      0.70               0.53
# Hawaii                       0.56               0.89
# North Carolina               0.52               1.00
# South Carolina               0.55               1.00

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(12,12))
mask = np.triu(final.loc['2017'].corr())
sns.heatmap(final.loc['2017'].corr(), annot = True, mask = mask);
plt.title('Heatmap for 2017 SAT and ACT data');

# %%
plt.figure(figsize=(12,12))
mask = np.triu(final.loc['2018'].corr())
sns.heatmap(final.loc['2018'].corr(), annot = True, mask = mask);
plt.title('Heatmap for 2018 SAT and ACT data');

# %%
plt.figure(figsize=(12,12))
mask = np.triu(final.corr())
sns.heatmap(final.corr(), annot = True, mask = mask,square = True);
plt.title('Heatmap for combined 2017 and 2018 SAT and ACT data');
plt.savefig('../images/sat_act_heatmap.png')

# %% [markdown]
# ### Negative correlations:
# ##### Participation rate of a given test vs participation rate of the opposite test:
# There is a **strong negative correlation** between participation rates for both tests (0.84 < |r| < 0.87). This makes sense as universities accept either test results and most students would select one test over the other. For states with mandatory testing for a given test, the opposite test would likely have a very low participation rate.
#
# ##### Test scores vs participation rate of the same test:
# Interestingly, there is a **strong negative correlation** between mean scores for a particular test and its participation rate. (0.76 < |r| < 0.87). This tells us that states that have a low participation rate for a given tend to score higher on average. This makes sense because for states with low participation rates, there is unlikely to be mandatory testing for a given test. The few students who take that particular test do so of their own choice and with a good amount of preparation, therefore tend to do better.
#
# ##### Test scores for a given test vs test scores for the opposite test:
# There is a **moderately negative correlation** between mean scores for a particular test and mean scores for the opposite test. (0.31 < |r| < 0.49). This is an indirect relationship resulting from the above correlations. For instance, states which have high participation for SATs tend to score lower on average for SATs. On the flipside, would have low participation for ACTs and tend to have a higher mean score for ACTs.
#
# ### Positive correlations:
# ##### Test scores vs other test scores of the same test (SAT or ACT):
# The mean scores for components for a particular test (SAT or ACT) exhibit a **high positive correlation** with one another (0.97 < |r| < 1). This indicates that students that perform well for a particular section of a test are likely to perform well in other sections of the same test.
#
# ##### Test participation vs test scores of another test:
# The mean scores for a given test type (eg. SAT) are **moderately positively correlated** with the participation rate for the opposite test (eg. ACT) (0.6 < |r| < 0.77). Again, this is explained indirectly due to states with high participation rates for a given test tend to have low participation rates for the opposite test, and thus have a higher mean score for the opposite test.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, ylabel):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,5))# You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    #list of colours
    colr = ['maroon','teal','khaki,','palegreen']
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], color = colr[i], edgecolor = 'black')# feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_title(list_of_titles[i], fontsize = 18)
        ax[i].set_ylabel(ylabel)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %% [markdown]
# #### Participation rates for SAT & ACT

# %%
subplot_histograms(final.loc['2017'],
                   ['sat_participation', 'act_participation'], 
                   ['2017 SAT participation rates','2017 ACT participation rates'],
                  ['SAT participation rate', 'ACT participation rate'],
                  'Number of states with X participation rate')

# %%
subplot_histograms(final.loc['2018'],
                   ['sat_participation', 'act_participation'], 
                   ['2018 SAT participation rates','2018 ACT participation rates'],
                  ['SAT participation rate', 'ACT participation rate'],
                  'Number of states with X participation rate')

# %% [markdown]
# ### Observations:
# We can observe two distinct peaks for the histograms showing participation rates for a given test for each year. This is characteristic of a bimodal distribution represented by two groups of states distinctly split by either high or low participation rates for a given test.

# %% [markdown]
# #### Math scores for SAT & ACT

# %%
final.loc['2017'].columns
# Out:
# Index(['sat_participation', 'sat_read_write', 'sat_math', 'sat_total',
#        'act_participation', 'act_english', 'act_math', 'act_reading',
#        'act_science', 'act_composite'],
#       dtype='object')

# %%
subplot_histograms(final.loc['2017'],
                   ['sat_math', 'act_math'], 
                   ['2017 SAT Math Scores','2017 ACT Math Scores'],
                  ['Average SAT Math Score', 'Average ACT Math Score'],
                  'Number of states with X average score')

# %%
subplot_histograms(final.loc['2018'],
                   ['sat_math', 'act_math'], 
                   ['2018 SAT Math Scores','2018 ACT Math Scores'],
                  ['Average SAT Math Score', 'Average ACT Math Score'],
                  'Number of states with X average score')

# %% [markdown]
# #### Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(final.loc['2017'],
                   ['sat_read_write', 'act_reading'], 
                   ['2017 SAT Read and Writing Scores','2017 ACT Reading Scores'],
                  ['Average SAT Read and Writing Score', 'Average ACT Reading Score'],
                  'Number of states with X average score')

# %%
subplot_histograms(final.loc['2017'],
                   ['sat_math', 'act_math'], 
                   ['2017 SAT Math Scores','2017 ACT Math Scores'],
                  ['Average SAT Math Score', 'Average ACT Math Score'],
                  'Number of states with x average math score')

# %% [markdown]
# ### Observations:
# The distributions for each test score appears to be bimodal. This is indicative of two groups of states, states which tend to score higher and states which tend to score lower on a particular test.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#Function to plot Scatterplots as subplots
def subplot_scatter(df, list_of_columns_x, list_of_columns_y, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns_x)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(13, 10)) # You'll want to specify your figsize
    ax = ax.ravel()
    for i, column_x in enumerate(list_of_columns_x):                  # Gives us an index and columns
        sns.scatterplot(data=df,
             x=column_x,
             y=list_of_columns_y[i],
             ax= ax[i], 
             s = 60,
             marker = 'o')       # Plotting scatterplots
        
        ax[i].set_title(list_of_titles[i], fontsize = 18)           # Set titles
        ax[i].set_xlabel(list_of_xlabels[i],fontsize = 14)  
        ax[i].set_ylabel(list_of_ylabels[i], fontsize = 14)
        # Set xlabels
    if len(list_of_columns_x) % 2 == 1:                             # Turn off odd number of subplots
        ax[-1].axis('off')
    sns.set(font_scale=1.5)    # Set scale for plots
    plt.tight_layout()         # Move the plots so they don't overlap

# %% [markdown]
# ### SAT vs. ACT  scores for analogous tests in 2017

# %%
#Using subplot function to plot 3 scatterplots at once
subplot_scatter(df = final.loc['2017'], 
                list_of_columns_x = ['sat_math', 'sat_read_write', 'sat_total'],
               list_of_columns_y = ['act_math', 'act_reading', 'act_composite'],
               list_of_titles = ['2017 SAT and ACT Math Scores for each State', '2017 SAT and ACT Reading Scores for each State', '2017 SAT total and ACT composite Scores for each State'],
               list_of_xlabels = ['SAT Math Score' ,'SAT Verbal Score', 'SAT Total Score'],
               list_of_ylabels = ['ACT Math Score' ,'ACT Reading Score', 'ACT Composite Score'])

# %% [markdown]
# ### Observations:
# Here we can visualize the moderate negative correlation between a particular test section and their counterparts for the opposite test. The correlation coefficient ranges between (0.31 < |r| < 0.49) as described on the heatmap.

# %% [markdown]
# ### Total SAT Scores 2017 vs. 2018

# %%
plt.figure(figsize = (12,12))
sns.scatterplot(data=final,
             x=final.loc['2017']['sat_total'],
             y=final.loc['2018']['sat_total'],
             s = 100,
             marker = 'o');       # Plotting scatterplots
plt.title('SAT total score 2017 vs 2018', fontsize = 18);
plt.xlabel('2017 SAT total', fontsize = 14);
plt.ylabel('2018 SAT total',fontsize = 14);
       # ax[i].set_title('Title', fontsize = 18)           # Set titles
      #  ax[i].set_xlabel('X',fontsize = 14)  
       # ax[i].set_ylabel('Y', fontsize = 14)

# %% [markdown]
# ### Composite scores for ACT 2017 vs. 2018

# %%
plt.figure(figsize = (12,12))
sns.scatterplot(data=final,
             x=final.loc['2017']['act_composite'],
             y=final.loc['2018']['act_composite'],
             s = 100,
             marker = 'o');       # Plotting scatterplots
plt.title('ACT Composite score 2017 vs 2018', fontsize = 18);
plt.xlabel('2017 ACT Composite', fontsize = 14);
plt.ylabel('2018 ACT Composite',fontsize = 14);

       # ax[i].set_title('Title', fontsize = 18)           # Set titles
      #  ax[i].set_xlabel('X',fontsize = 14)  
       # ax[i].set_ylabel('Y', fontsize = 14)

# %% [markdown]
# ### Observations:
#
# The scatterplots above describe a strong positive correlation between test scores for a particular test for both years. Interesting points of study would be the outlier points, which show a stark change in mean test scores from year to year.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.loc['2017'].head()
# Out:
#             sat_participation  sat_read_write  sat_math  sat_total  \
# State
# Alabama                  0.05             593       572       1165
# Alaska                   0.38             547       533       1080
# Arizona                  0.30             563       553       1116
# Arkansas                 0.03             614       594       1208
# California               0.53             531       524       1055
#
#             act_participation  act_english  act_math  act_reading  \
# State
# Alabama                  1.00         18.9      18.4         19.7
# Alaska                   0.65         18.7      19.8         20.4
# Arizona                  0.62         18.6      19.8         20.1
# Arkansas                 1.00         18.9      19.0         19.7
# California               0.31         22.5      22.7         23.1
#
#             act_science  act_composite
# State
# Alabama            19.4           19.2
# Alaska             19.9           19.8
# ...

# %%
def subplot_box(df, list_of_titles, list_of_xlabels, list_of_ylabels,ticks,size):
    nrows = int(np.ceil(len(list_of_xlabels)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=size) # You'll want to specify your figsize
    ax = ax.ravel()
    for i, column_x in enumerate(df):                  # Gives us an index and columns
        sns.boxplot(data=df[i],
             ax= ax[i])       # Plotting scatterplots
        
        ax[i].set_title(list_of_titles[i], fontsize = 18)           # Set titles
        ax[i].set_xlabel(list_of_xlabels[i],fontsize = 14)          # Set xlabels
        ax[i].set_ylabel(list_of_ylabels[i],fontsize = 14)
        ax[i].set_xticks(range(len(ticks)))
        ax[i].set_xticklabels(ticks)
        
    if len(list_of_titles) % 2 == 1:                             # Turn off odd number of subplots
        ax[-1].axis('off')
    sns.set(font_scale=1.5)    # Set scale for plots
    plt.tight_layout()         # Move the plots so they don't overlap

# %%
subplot_box(df = [[final.loc['2017']['sat_participation'],final.loc['2018']['sat_participation']],
                 [final.loc['2017']['act_participation'],final.loc['2018']['act_participation']]],
              list_of_titles = ['SAT Participation for 2017 and 2018','ACT Participation for 2017 and 2018'], 
              list_of_xlabels = ['SAT Participation','ACT Participation'],
              list_of_ylabels = ['Participation Rate', 'Participation Rate'],
              ticks = ['2017','2018'],
              size = (12,8));

# %% [markdown]
# ### Observations:
#
# There is a significant increase in SAT participation and a slight decrease in average ACT participation from 2017 to 2018.

# %%
subplot_box(df = [[final.loc['2017']['sat_math'],final.loc['2018']['sat_math']],
                 [final.loc['2017']['sat_read_write'],final.loc['2018']['sat_read_write']],
                 [final.loc['2017']['sat_total'],final.loc['2018']['sat_total']]],
              list_of_titles = ['SAT Math Scores for 2017 and 2018','SAT Verbal Scores for 2017 and 2018','SAT Total Scores for 2017 and 2018'], 
              list_of_xlabels = ['SAT Math','SAT Verbal','SAT Total'],
              list_of_ylabels = ['Score','Score','Score'],
              ticks = ['2017','2018'],
              size = (12,12));

# %%
final.loc['2017'].columns
# Out:
# Index(['sat_participation', 'sat_read_write', 'sat_math', 'sat_total',
#        'act_participation', 'act_english', 'act_math', 'act_reading',
#        'act_science', 'act_composite'],
#       dtype='object')

# %%
subplot_box(df = [[final.loc['2017']['act_english'],final.loc['2018']['act_english']],
                 [final.loc['2017']['act_math'],final.loc['2018']['act_math']],
                 [final.loc['2017']['act_reading'],final.loc['2018']['act_reading']],
                 [final.loc['2017']['act_science'],final.loc['2018']['act_science']],
                 [final.loc['2017']['act_composite'],final.loc['2018']['act_composite']]],
            list_of_titles = ['ACT English Scores for 2017 and 2018','ACT Math Scores for 2017 and 2018','ACT Reading Scores for 2017 and 2018','ACT Science Scores for 2017 and 2018','ACT Composite Scores for 2017 and 2018'], 
            list_of_xlabels = ['ACT English','ACT Math','ACT Reading','ACT Science','ACT Composite'],
            list_of_ylabels = ['Score','Score','Score','Score','Score'],
            ticks = ['2017','2018'],
            size = (20,25));

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
difference_sat = final.loc['2018']['sat_participation'] - final.loc['2017']['sat_participation']

# %%
difference_sat
# Out:
# State
# Alabama                 0.01
# Alaska                  0.05
# Arizona                -0.01
# Arkansas                0.02
# California              0.07
# Colorado                0.89
# Connecticut             0.00
# Delaware                0.00
# District of Columbia   -0.08
# Florida                -0.27
# Georgia                 0.09
# Hawaii                  0.01
# Idaho                   0.07
# Illinois                0.90
# Indiana                 0.00
# Iowa                    0.01
# Kansas                  0.00
# Kentucky                0.00
# Louisiana               0.00
# Maine                   0.04
# Maryland                0.07
# Massachusetts           0.04
# Michigan                0.00
# Minnesota               0.01
# Mississippi             0.01
# Missouri                0.01
# Montana                 0.00
# Nebraska                0.00
# Nevada                 -0.03
# New Hampshire           0.00
# New Jersey              0.12
# New Mexico              0.05
# ...

# %%
difference_act = final.loc['2018']['act_participation'] - final.loc['2017']['act_participation']
difference_act
# Out:
# State
# Alabama                 0.00
# Alaska                 -0.32
# Arizona                 0.04
# Arkansas                0.00
# California             -0.04
# Colorado               -0.70
# Connecticut            -0.05
# Delaware               -0.01
# District of Columbia    0.00
# Florida                -0.07
# Georgia                -0.02
# Hawaii                 -0.01
# Idaho                  -0.02
# Illinois               -0.50
# Indiana                -0.03
# Iowa                    0.01
# Kansas                 -0.02
# Kentucky                0.00
# Louisiana               0.00
# Maine                  -0.01
# Maryland                0.03
# Massachusetts          -0.04
# Michigan               -0.07
# Minnesota              -0.01
# Mississippi             0.00
# Missouri                0.00
# Montana                 0.00
# Nebraska                0.16
# Nevada                  0.00
# New Hampshire          -0.02
# New Jersey             -0.03
# New Mexico              0.01
# ...

# %%
difference = pd.concat ([difference_sat, difference_act], axis = 1)

# %%
difference.sort_values(by ='sat_participation', ascending = False).head(3)
# Out:
#               sat_participation  act_participation
# State
# Illinois                   0.90              -0.50
# Colorado                   0.89              -0.70
# Rhode Island               0.26              -0.06

# %%
difference.sort_values(by ='sat_participation', ascending = True).head(3)
# Out:
#                       sat_participation  act_participation
# State
# Florida                           -0.27              -0.07
# District of Columbia              -0.08               0.00
# Nevada                            -0.03               0.00

# %%
difference.sort_values(by ='act_participation', ascending = False).head(3)
# Out:
#           sat_participation  act_participation
# State
# Ohio                   0.06               0.25
# Nebraska               0.00               0.16
# Arizona               -0.01               0.04

# %%
difference.sort_values(by ='act_participation', ascending = True).head(3)
# Out:
#           sat_participation  act_participation
# State
# Colorado               0.89              -0.70
# Illinois               0.90              -0.50
# Alaska                 0.05              -0.32

# %%
sat_percent = difference_sat / (final.loc['2017']['sat_participation']) * 100

# %%
act_percent = difference_act / (final.loc['2017']['act_participation'])* 100

# %%
participations = pd.concat([final.loc['2017']['sat_participation'],final.loc['2018']['sat_participation'],difference_sat,sat_percent,final.loc['2017']['act_participation'],final.loc['2018']['act_participation'], difference_act,act_percent], axis = 1)

# %%
participations.columns = ['sat_2017','sat_2018','sat_difference','sat_percent_change','act_2017','act_2018','act_difference','act_percent_change']

# %%
participations.sort_values(by = 'act_percent_change', ascending = False)
# Out:
#                       sat_2017  sat_2018  sat_difference  sat_percent_change  \
# State
# Ohio                      0.12      0.18            0.06           50.000000
# Nebraska                  0.03      0.03            0.00            0.000000
# Maryland                  0.69      0.76            0.07           10.144928
# Arizona                   0.30      0.29           -0.01           -3.333333
# Oregon                    0.43      0.48            0.05           11.627907
# New Mexico                0.11      0.16            0.05           45.454545
# Iowa                      0.02      0.03            0.01           50.000000
# North Carolina            0.49      0.52            0.03            6.122449
# Montana                   0.10      0.10            0.00            0.000000
# Nevada                    0.26      0.23           -0.03          -11.538462
# Alabama                   0.05      0.06            0.01           20.000000
# ...

# %%
total_2017 = participations['sat_2017'] + participations['act_2017']
total_2018 = participations['sat_2018'] + participations['act_2018']
sat_share_2017 = participations['sat_2017'] / total_2017
sat_share_2018 = participations['sat_2018'] / total_2018

# %%
participations['total_2017'] = total_2017
participations['total_2018'] = total_2018
participations['sat_share_2017'] = sat_share_2017
participations['sat_share_2018'] = sat_share_2018

# %%
participations.to_csv('../data/participation_rates.csv')

# %% [markdown]
# Interesting states to look at :
#
# 1) **South Carolina** - ACT is mandatory, yet >50% of students are taking SATs. Strategy to get state to switch mandatory testing from ACT to SAT
#
# 2) **Alaska** - 50% decrease in ACT participation from 2017 to 2018 (65% to  33%), yet SAT participation only improved by 13% (38% to 43%). There is opportunity there
#
# 3) **West Virginia** - 100% increase in SAT participation from 2017 to 2018 (14% to 28%) indicating a significant increase in interest amongst the student population. Yet, ACT is predominant there.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename ="../images/SAT_2018.png")

# %%
Image(filename ="../images/SAT_share_2018.png")

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        sat_participation  sat_read_write    sat_math    sat_total  \
# count         102.000000      102.000000  102.000000   102.000000
# mean            0.427745      566.401961  556.558824  1123.058824
# std             0.362527       46.442823   47.213770    92.915678
# min             0.020000      480.000000  468.000000   950.000000
# 25%             0.040000      534.250000  523.000000  1055.250000
# 50%             0.455000      554.500000  545.500000  1099.000000
# 75%             0.700000      613.500000  595.000000  1209.500000
# max             1.000000      644.000000  655.000000  1298.000000
#
#        act_participation  act_english    act_math  act_reading  act_science  \
# count         102.000000   102.000000  102.000000   102.000000   102.000000
# mean            0.634510    20.959804   21.153922    22.014706    21.398039
# std             0.330105     2.388722    1.999291     2.107337     1.797742
# ...

# %% [markdown]
# #### Answers:
#
# Based on the above histograms, all the variables take up a **bimodal distribution** as there are two distinct peaks. This is a combindation of 2 normal distributions and is indicative of two groups of states for each variable.
#
# For example, for test scores, there are two groups of states one of which tends to score higher and the other which tends to score lower on a particular test.
#
# For participation rates, the two groups of states are one which tends to have low participation rates in a certain test and the other group which tends to have high participation rates for the same test.
#
# Using the .describe() method, we observe that the spread of data for participation rates is much higher than for test scores, indicating a larger distance between the two modes for participation rates as compared to test scores.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# #### Answer:
# Yes, as stated earlier, the bimodal distribution observed is a combination of 2 normal distributions. One representing states which tend to score lower/participate less on a given test, and the other representing states which tend to score higher/participate more on a given test.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# #### Answer:
# Yes. However more accurately estimate a normal distribution, the data may have to be split in two. The median for each variable can be used as a rough separator for the two distributions.
#
# The assumption does hold true for math, reading and rate variables. However the distance between the two modes is much more significant in rates, therefore the normal distributions are more distinct. For test scores, the modes are closer to one another.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# #### Answer:
# To an extent, yes, as SAT and ACT participation in 2017 exhibit a strong negative correlation with a coefficient of -0.84. However, it is not exactly a direct inverse relationship. In reality, these participation rates are drawn from the same population of students. Students may choose to take one test or the other, or both. Therefore, additional data would certainly help to supplement the statistical analysis.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# #### Answer:
# SAT and ACT math scores in 2017 exhibit a moderately negative correlation with a coefficient of -0.38. This tells us that there is somewhat of an underlying relationship between the two scores although it is moderate. Furthermore, the scoring system for these tests is quite different and makes it difficult to place them side by side. (200 - 800 for SATs, and 1 - 36 for ACTs). Therefore it is not very useful to compare the math scores with one another.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
final.loc['2017'].describe()
# Out:
#        sat_participation  sat_read_write    sat_math    sat_total  \
# count          51.000000       51.000000   51.000000    51.000000
# mean            0.398039      569.117647  556.882353  1126.098039
# std             0.352766       45.666901   47.121395    92.494812
# min             0.020000      482.000000  468.000000   950.000000
# 25%             0.040000      533.500000  523.500000  1055.500000
# 50%             0.380000      559.000000  548.000000  1107.000000
# 75%             0.660000      613.000000  599.000000  1212.000000
# max             1.000000      644.000000  651.000000  1295.000000
#
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.652549    20.931373  21.182353    22.013725    21.450980
# std             0.321408     2.353677   1.981989     2.067271     1.739353
# ...

# %%
final.loc['2018'].describe()
# Out:
#        sat_participation  sat_read_write    sat_math    sat_total  \
# count          51.000000       51.000000   51.000000    51.000000
# mean            0.457451      563.686275  556.235294  1120.019608
# std             0.373143       47.502627   47.772623    94.155083
# min             0.020000      480.000000  480.000000   977.000000
# 25%             0.045000      534.500000  522.500000  1057.500000
# 50%             0.520000      552.000000  544.000000  1098.000000
# 75%             0.775000      610.500000  593.500000  1204.000000
# max             1.000000      643.000000  655.000000  1298.000000
#
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.616471    20.988235  21.125490    22.015686    21.345098
# std             0.340810     2.446356   2.035765     2.167245     1.870114
# ...

# %%
final.loc['2018'].shape
# Out:
# (51, 10)

# %%
import scipy.stats as stats

# %% [markdown]
# H0: The mean participation rates for SAT is not greater in 2018 than in 2017
# HA: The mean participation rates for SAT is greater in 2018 than in 2017.
#
# Test at a 95% confidence interval

# %%
# Code: 
result = stats.ttest_ind_from_stats(mean1 = 0.457451, std1 = 0.373143, nobs1 = 51, mean2 = 0.398039, std2 = 0.352766, nobs2 = 51, equal_var=True, alternative='greater')

# %%
result
# Out:
# Ttest_indResult(statistic=0.8262681961334578, pvalue=0.20530952067428576)

# %% [markdown]
# Calculated p-value is **0.205** > 0.05. Therefore we **do not reject the null hypothesis.** At a 95% confidence interval, we cannot say that the SAT 2017 mean total score increased from 2017 to 2018.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
participations.sort_values(by = 'sat_difference', ascending = False).head(3)
# Out:
#               sat_2017  sat_2018  sat_difference  sat_percent_change  \
# State
# Illinois          0.09      0.99            0.90         1000.000000
# Colorado          0.11      1.00            0.89          809.090909
# Rhode Island      0.71      0.97            0.26           36.619718
#
#               act_2017  act_2018  act_difference  act_percent_change  \
# State
# Illinois          0.93      0.43           -0.50          -53.763441
# Colorado          1.00      0.30           -0.70          -70.000000
# Rhode Island      0.21      0.15           -0.06          -28.571429
#
#               total_2017  total_2018  sat_share_2017  sat_share_2018
# State
# Illinois            1.02        1.42        0.088235        0.697183
# Colorado            1.11        1.30        0.099099        0.769231
# Rhode Island        0.92        1.12        0.771739        0.866071

# %%
participations.sort_values(by = 'act_difference', ascending = True).head(3)
# Out:
#           sat_2017  sat_2018  sat_difference  sat_percent_change  act_2017  \
# State
# Colorado      0.11      1.00            0.89          809.090909      1.00
# Illinois      0.09      0.99            0.90         1000.000000      0.93
# Alaska        0.38      0.43            0.05           13.157895      0.65
#
#           act_2018  act_difference  act_percent_change  total_2017  \
# State
# Colorado      0.30           -0.70          -70.000000        1.11
# Illinois      0.43           -0.50          -53.763441        1.02
# Alaska        0.33           -0.32          -49.230769        1.03
#
#           total_2018  sat_share_2017  sat_share_2018
# State
# Colorado        1.30        0.099099        0.769231
# Illinois        1.42        0.088235        0.697183
# Alaska          0.76        0.368932        0.565789

# %% [markdown]
# 1) Colorado.
#
# SAT participation increased from 11% to 100%, while ACT participation dropped from 100% to 30%. This was due to the shift in state policy mandating SATs instead of ACTs. [Source: Colorado Changed to the SAT in 2017: What You Need to Know](https://www.testive.com/colorado-sat-change-2017/)
#
# 2) Illinois
#
# SAT participation increased from 9% to 99%, while ACT participation dropped from 93% to 43%. This was due to the state policy switching its mandatory testing requirements from ACT to SATs. [Source: Chicago Tribune - Illinois moves ahead with new testing plan, replacing ACT with SAT](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
#
# 3) Alaska
#
# SAT participation increased slightly from 38% to 43%, but ACT participation dropped significantly from 65% to 33%. This was due to the state removing its mandatory testing requirements. Starting from 2017, students from Alaska would no longer need require standardized testing to graduate from high school. [Source: Anchorage Daily News - Alaska high school students no longer need national tests to graduate](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/)

# %% [markdown]
# From the findings, the above 3 states were the largest contributors to the overall increase in SAT participation and overall decrease in ACT participations. Each of these major changes were a result of state policy changes after political lobbying by College Board.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# #### Conclusions
#
# - SAT and ACT participation rates show a strong negative correlation implying that states tend to lean towards favouring one test over the other. This is partly driven by state policy which mandates taking either test to graduate from high school or apply for college. This is also driven by the fact that most US universities accept either test, hence given the choice, students are likely to select one test that they are more comfortable with over the other.
#
#
# - Participation rates and test scores are negatively correlated, which tells us that states with high participation rates for a certain test tend to have a lower mean score for that test and vice versa.
#
#
# - The largest changes in participation rates from 2017 to 2018 were driven by changes in state policy mandating one test over the other.

# %% [markdown]
# #### Recommendations:
#
# Given the conclusions drawn from our analysis, the most effective method to increase participation rate is to convert a state's mandate from taking the ACTs to taking the SATs. This involves investing in political lobbying in select states in an effort to change state regulations. As such, 3 states were selected to channel resources into:
#
# 1) **South Carolina**
# - ACT testing is mandatory (100% participation for both years), yet > 50% of students are taking SATs. The participation rate even increased from 50% in 2017 to 55% in 2018. This tells us that despite ACTs being compulsory, a majority of students are also choosing to take the SATs as well, indicating a strong interest in SATs in that state. With increased public support for the SATs, it may be easier to secure a bid to change the state policy there.
#
# 2) **Alaska**
# - Mandatory testing was dropped in 2016 resulting in a 50% decrease in ACT participation from 2017 to 2018 (65% to 33%). Yet SAT participation improved by 13% (38% to 43%), showing that students in Alaska continue to show increased interest in taking the SATs. It would make sense to take advantage of the current trend to increase its rate of growth.
#
# 3) **West Virginia**
# - ACT is predominant in this state with 69% participation in 2017 and 65% participation in 2018. Yet there was a significant increase in SAT participation from 14% in 2017 to 28% in 2018. This is a 100% increase, indicating a strong interest among students there to take the SATs. This can make for a strong case when bidding for state contracts mandating standardized testing. Furthermore, West Virginia was amongst the bottom scoring states for the SATs in 2018. This shows that despite the increased interest, there is a need for additional student resources to better prepare them for the test.

# %% [markdown]
# ## Sources and Citations

# %% [markdown]
# - [A (Mostly) Brief History Of The SAT And ACT Tests](https://www.erikthered.com/tutor/sat-act-history.html#y2011)
# - [2017 Maryland SAT Suite of Assessments Annual Report](https://reports.collegeboard.org/pdf/2017-maryland-sat-suite-assessments-annual-report.pdf-0)
# - [ACT 2017 Average Scores by State](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf)
# - [Colorado Changed to the SAT in 2017: What You Need to Know](https://www.testive.com/colorado-sat-change-2017/)
# - [Chicago Tribune - Illinois moves ahead with new testing plan, replacing ACT with SAT](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# - [Anchorage Daily News - Alaska high school students no longer need national tests to graduate](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/)
